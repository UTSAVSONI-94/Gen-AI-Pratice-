# %% [markdown]
# ##load env variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-3.6-flash")

# %%
res = llm.invoke("Who was the winner of IPL 2020?")
print(res.content)
# Out:
# [{'type': 'text', 'text': 'The winner of IPL 2020 was the **Mumbai Indians**. They defeated the Delhi Capitals by 5 wickets in the final to win their 5th IPL title.', 'extras': {'signature': '...'}}]
